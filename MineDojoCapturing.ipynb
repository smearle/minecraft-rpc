# %%
from dojo import MineDojoSpawner, Structure
import numpy as np
from PIL import Image
# Out:
# [INFO:minedojo.tasks] Loaded 1572 Programmatic tasks, 1558 Creative tasks, and 1 special task: "Playthrough". Totally 3131 tasks loaded.

# %%
z = np.zeros((5, 4, 6))
z[:, :, -1] = 3
z[0, :, :] = 2
z[-1, :, :] = 1

z = z.astype(int)

# %%
structure = Structure(z, blocks = ["diamond_ore", "obsidian", "dirt", "stone"])

# %%
spawner = MineDojoSpawner()
# Out:
# [INFO:minedojo.tasks] Loaded 1572 Programmatic tasks, 1558 Creative tasks, and 1 special task: "Playthrough". Totally 3131 tasks loaded.

# %%
faces = spawner.capture_rotations(structure)

# %%
def image_grid(imgs, rows, cols):
    assert len(imgs) == rows*cols

    w, h = imgs[0].size
    grid = Image.new('RGB', size=(cols*w, rows*h))
    grid_w, grid_h = grid.size
    
    for i, img in enumerate(imgs):
        grid.paste(img, box=(i%cols*w, i//cols*h))
    return grid

# %%
image_grid(faces.images(), 2, 2)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>
